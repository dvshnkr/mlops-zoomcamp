# %%
import xgboost as xgb
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import mlflow
import hyperopt

sns.set_theme()

# %%
# %cd ../..
# Out:
# C:\Users\devsn\Desktop\courses\MLOps Zoomcamp

# %%
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("iris-classification")
# Out:
# 2023/07/16 01:44:13 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2023/07/16 01:44:13 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2023/07/16 01:44:13 INFO mlflow.tracking.fluent: Experiment with name 'iris-classification' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///C:/Users/devsn/Desktop/courses/MLOps Zoomcamp/mlruns/3', creation_time=1689452053378, experiment_id='3', last_update_time=1689452053378, lifecycle_stage='active', name='iris-classification', tags={}>

# %%
X, y = load_iris(return_X_y=True)

X.shape, y.shape
# Out:
# ((150, 4), (150,))

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
np.unique(y)
# Out:
# array([0, 1, 2])

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=42)

# %%
dtrain = xgb.DMatrix(X_train, y_train)
dval = xgb.DMatrix(X_val, y_val)

# %%
from hyperopt import fmin, hp, tpe, Trials, STATUS_OK
from hyperopt.pyll import scope
from sklearn.metrics import mean_squared_error

# %%
exp(-1), exp(0)
# Out:
# (0.36787944117144233, 1.0)

# %%
space = {
    "max_depth": scope.int(hp.quniform('max_depth', 5.5, 20.5, 1)),
    "eta": hp.loguniform('eta', -3, 0), 
    "subsample": hp.uniform('subsample', 0.5, 1),
    "lambda": hp.loguniform('lambda', -5, 0),
    "alpha": hp.loguniform('alpha', -5, 0),
    "num_class": 3,
    "objective": "multi:softmax",
    "seed": 42
}


watchlist = [(dval, "eval"), (dtrain, "train")]
# eval_metric = "mlogloss"
num_round = 100 # number of boosting rounds = number of estimators
early_stopping_rounds = 50

def objective(params):
    with mlflow.start_run():
        
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        
        booster = xgb.train(
            params=params,
            dtrain=dtrain,
            num_boost_round=num_round,
            evals=watchlist,
            early_stopping_rounds=early_stopping_rounds
        )
        
        y_pred = booster.predict(dval)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        
        mlflow.log_metric("RMSE", rmse)
    
    return {"loss": rmse, "status": STATUS_OK}


trials = Trials()

# %%
best = fmin(
    fn=objective,
    space=space,
    algo=tpe.suggest,
    trials=trials,
    max_evals=10
)
# Out:
# [0]	eval-mlogloss:0.97744	train-mlogloss:0.98287
# [1]	eval-mlogloss:0.87523	train-mlogloss:0.88348
# [2]	eval-mlogloss:0.78838	train-mlogloss:0.79995
# [3]	eval-mlogloss:0.71195	train-mlogloss:0.72689
# [4]	eval-mlogloss:0.64491	train-mlogloss:0.66179
# [5]	eval-mlogloss:0.58144	train-mlogloss:0.60337
# [6]	eval-mlogloss:0.52672	train-mlogloss:0.55029
# [7]	eval-mlogloss:0.47821	train-mlogloss:0.50474
# [8]	eval-mlogloss:0.43522	train-mlogloss:0.46185
# [9]	eval-mlogloss:0.39525	train-mlogloss:0.42398
# [10]	eval-mlogloss:0.35956	train-mlogloss:0.39136
# [11]	eval-mlogloss:0.32837	train-mlogloss:0.36026
# [12]	eval-mlogloss:0.29946	train-mlogloss:0.33348
# [13]	eval-mlogloss:0.27496	train-mlogloss:0.30731
# [14]	eval-mlogloss:0.25275	train-mlogloss:0.28437
# [15]	eval-mlogloss:0.23414	train-mlogloss:0.26340
# [16]	eval-mlogloss:0.21605	train-mlogloss:0.24339
# [17]	eval-mlogloss:0.19795	train-mlogloss:0.22664
# [18]	eval-mlogloss:0.18271	train-mlogloss:0.21182
# [19]	eval-mlogloss:0.16829	train-mlogloss:0.19675
# [20]	eval-mlogloss:0.15468	train-mlogloss:0.18421
# [21]	eval-mlogloss:0.14318	train-mlogloss:0.17231
# [22]	eval-mlogloss:0.13327	train-mlogloss:0.16145
# [23]	eval-mlogloss:0.12249	train-mlogloss:0.15151
# [24]	eval-mlogloss:0.11356	train-mlogloss:0.14249
# [25]	eval-mlogloss:0.10459	train-mlogloss:0.13464
# [26]	eval-mlogloss:0.09687	train-mlogloss:0.12632
# [27]	eval-mlogloss:0.09064	train-mlogloss:0.11747
# [28]	eval-mlogloss:0.08418	train-mlogloss:0.11077
# [29]	eval-mlogloss:0.07829	train-mlogloss:0.10469
# [30]	eval-mlogloss:0.07342	train-mlogloss:0.09853
# [31]	eval-mlogloss:0.07001	train-mlogloss:0.09331
# [32]	eval-mlogloss:0.06722	train-mlogloss:0.08890
# [33]	eval-mlogloss:0.06407	train-mlogloss:0.08406
# [34]	eval-mlogloss:0.06141	train-mlogloss:0.08042
# [35]	eval-mlogloss:0.05668	train-mlogloss:0.07696
# [36]	eval-mlogloss:0.05313	train-mlogloss:0.07289
# [37]	eval-mlogloss:0.05006	train-mlogloss:0.06923
# [38]	eval-mlogloss:0.04733	train-mlogloss:0.06635
# [39]	eval-mlogloss:0.04460	train-mlogloss:0.06413
# [40]	eval-mlogloss:0.04207	train-mlogloss:0.06143
# [41]	eval-mlogloss:0.04055	train-mlogloss:0.05941
# [42]	eval-mlogloss:0.03844	train-mlogloss:0.05753
# [43]	eval-mlogloss:0.03710	train-mlogloss:0.05546
# [44]	eval-mlogloss:0.03611	train-mlogloss:0.05385
# [45]	eval-mlogloss:0.03459	train-mlogloss:0.05213
# [46]	eval-mlogloss:0.03335	train-mlogloss:0.05050
# [47]	eval-mlogloss:0.03148	train-mlogloss:0.04890
# [48]	eval-mlogloss:0.03002	train-mlogloss:0.04790
# [49]	eval-mlogloss:0.02858	train-mlogloss:0.04669
# [50]	eval-mlogloss:0.02736	train-mlogloss:0.04566
# [51]	eval-mlogloss:0.02703	train-mlogloss:0.04461
# [52]	eval-mlogloss:0.02676	train-mlogloss:0.04401
# [53]	eval-mlogloss:0.02639	train-mlogloss:0.04363
# [54]	eval-mlogloss:0.02599	train-mlogloss:0.04310
# [55]	eval-mlogloss:0.02546	train-mlogloss:0.04217
# [56]	eval-mlogloss:0.02531	train-mlogloss:0.04165
# [57]	eval-mlogloss:0.02498	train-mlogloss:0.04102
# [58]	eval-mlogloss:0.02438	train-mlogloss:0.04048
# [59]	eval-mlogloss:0.02419	train-mlogloss:0.04009
# [60]	eval-mlogloss:0.02341	train-mlogloss:0.03952
# [61]	eval-mlogloss:0.02351	train-mlogloss:0.03919
# [62]	eval-mlogloss:0.02264	train-mlogloss:0.03863
# [63]	eval-mlogloss:0.02282	train-mlogloss:0.03841
# [64]	eval-mlogloss:0.02246	train-mlogloss:0.03805
# [65]	eval-mlogloss:0.02189	train-mlogloss:0.03763
# [66]	eval-mlogloss:0.02185	train-mlogloss:0.03739
# [67]	eval-mlogloss:0.02164	train-mlogloss:0.03703
# [68]	eval-mlogloss:0.02168	train-mlogloss:0.03675
# [69]	eval-mlogloss:0.02120	train-mlogloss:0.03636
# [70]	eval-mlogloss:0.02120	train-mlogloss:0.03582
# [71]	eval-mlogloss:0.02129	train-mlogloss:0.03557
# [72]	eval-mlogloss:0.02081	train-mlogloss:0.03534
# [73]	eval-mlogloss:0.02022	train-mlogloss:0.03525
# [74]	eval-mlogloss:0.02028	train-mlogloss:0.03486
# [75]	eval-mlogloss:0.02011	train-mlogloss:0.03464
# [76]	eval-mlogloss:0.02029	train-mlogloss:0.03441
# [77]	eval-mlogloss:0.02035	train-mlogloss:0.03412
# [78]	eval-mlogloss:0.01950	train-mlogloss:0.03373
# [79]	eval-mlogloss:0.01873	train-mlogloss:0.03352
# [80]	eval-mlogloss:0.01821	train-mlogloss:0.03330
# [81]	eval-mlogloss:0.01774	train-mlogloss:0.03320
# [82]	eval-mlogloss:0.01793	train-mlogloss:0.03296
# [83]	eval-mlogloss:0.01777	train-mlogloss:0.03284
# [84]	eval-mlogloss:0.01767	train-mlogloss:0.03278
# [85]	eval-mlogloss:0.01753	train-mlogloss:0.03261
# [86]	eval-mlogloss:0.01780	train-mlogloss:0.03246
# [87]	eval-mlogloss:0.01753	train-mlogloss:0.03232
# [88]	eval-mlogloss:0.01764	train-mlogloss:0.03218
# [89]	eval-mlogloss:0.01732	train-mlogloss:0.03202
# [90]	eval-mlogloss:0.01774	train-mlogloss:0.03178
# [91]	eval-mlogloss:0.01742	train-mlogloss:0.03161
# [92]	eval-mlogloss:0.01745	train-mlogloss:0.03147
# [93]	eval-mlogloss:0.01739	train-mlogloss:0.03145
# [94]	eval-mlogloss:0.01736	train-mlogloss:0.03126
# [95]	eval-mlogloss:0.01724	train-mlogloss:0.03106
# [96]	eval-mlogloss:0.01741	train-mlogloss:0.03102
# [97]	eval-mlogloss:0.01728	train-mlogloss:0.03080
# [98]	eval-mlogloss:0.01733	train-mlogloss:0.03059
# [99]	eval-mlogloss:0.01712	train-mlogloss:0.03044
# [0]	eval-mlogloss:0.79885	train-mlogloss:0.81918
# [1]	eval-mlogloss:0.60006	train-mlogloss:0.63166
# [2]	eval-mlogloss:0.46048	train-mlogloss:0.49842
# [3]	eval-mlogloss:0.35959	train-mlogloss:0.39876
# [4]	eval-mlogloss:0.28303	train-mlogloss:0.32191
# [5]	eval-mlogloss:0.22673	train-mlogloss:0.26393
# [6]	eval-mlogloss:0.18165	train-mlogloss:0.21657
# [7]	eval-mlogloss:0.14673	train-mlogloss:0.18000
# [8]	eval-mlogloss:0.11992	train-mlogloss:0.15113
# [9]	eval-mlogloss:0.09833	train-mlogloss:0.12837
# [10]	eval-mlogloss:0.07999	train-mlogloss:0.11067
# [11]	eval-mlogloss:0.06733	train-mlogloss:0.09542
# [12]	eval-mlogloss:0.05566	train-mlogloss:0.08299
# [13]	eval-mlogloss:0.04699	train-mlogloss:0.07220
# [14]	eval-mlogloss:0.04218	train-mlogloss:0.06365
# [15]	eval-mlogloss:0.03675	train-mlogloss:0.05740
# [16]	eval-mlogloss:0.03406	train-mlogloss:0.05288
# [17]	eval-mlogloss:0.03152	train-mlogloss:0.04876
# [18]	eval-mlogloss:0.02765	train-mlogloss:0.04460
# [19]	eval-mlogloss:0.02532	train-mlogloss:0.04092
# [20]	eval-mlogloss:0.02282	train-mlogloss:0.03846
# [21]	eval-mlogloss:0.02108	train-mlogloss:0.03651
# [22]	eval-mlogloss:0.02065	train-mlogloss:0.03562
# [23]	eval-mlogloss:0.01974	train-mlogloss:0.03476
# [24]	eval-mlogloss:0.01934	train-mlogloss:0.03409
# [25]	eval-mlogloss:0.01897	train-mlogloss:0.03346
# [26]	eval-mlogloss:0.01878	train-mlogloss:0.03271
# [27]	eval-mlogloss:0.01836	train-mlogloss:0.03220
# [28]	eval-mlogloss:0.01818	train-mlogloss:0.03176
# [29]	eval-mlogloss:0.01790	train-mlogloss:0.03144
# [30]	eval-mlogloss:0.01741	train-mlogloss:0.03094
# [31]	eval-mlogloss:0.01742	train-mlogloss:0.03059
# [32]	eval-mlogloss:0.01735	train-mlogloss:0.03003
# [33]	eval-mlogloss:0.01676	train-mlogloss:0.02951
# [34]	eval-mlogloss:0.01640	train-mlogloss:0.02920
# [35]	eval-mlogloss:0.01623	train-mlogloss:0.02871
# [36]	eval-mlogloss:0.01616	train-mlogloss:0.02826
# [37]	eval-mlogloss:0.01595	train-mlogloss:0.02798
# [38]	eval-mlogloss:0.01578	train-mlogloss:0.02775
# [39]	eval-mlogloss:0.01556	train-mlogloss:0.02732
# [40]	eval-mlogloss:0.01546	train-mlogloss:0.02709
# [41]	eval-mlogloss:0.01537	train-mlogloss:0.02692
# [42]	eval-mlogloss:0.01504	train-mlogloss:0.02672
# [43]	eval-mlogloss:0.01495	train-mlogloss:0.02658
# [44]	eval-mlogloss:0.01497	train-mlogloss:0.02645
# [45]	eval-mlogloss:0.01488	train-mlogloss:0.02629
# [46]	eval-mlogloss:0.01471	train-mlogloss:0.02600
# [47]	eval-mlogloss:0.01439	train-mlogloss:0.02582
# [48]	eval-mlogloss:0.01424	train-mlogloss:0.02570
# [49]	eval-mlogloss:0.01426	train-mlogloss:0.02556
# [50]	eval-mlogloss:0.01394	train-mlogloss:0.02541
# [51]	eval-mlogloss:0.01378	train-mlogloss:0.02523
# [52]	eval-mlogloss:0.01374	train-mlogloss:0.02498
# [53]	eval-mlogloss:0.01369	train-mlogloss:0.02488
# [54]	eval-mlogloss:0.01374	train-mlogloss:0.02477
# [55]	eval-mlogloss:0.01359	train-mlogloss:0.02462
# [56]	eval-mlogloss:0.01370	train-mlogloss:0.02456
# [57]	eval-mlogloss:0.01374	train-mlogloss:0.02446
# [58]	eval-mlogloss:0.01361	train-mlogloss:0.02436
# [59]	eval-mlogloss:0.01366	train-mlogloss:0.02428
# [60]	eval-mlogloss:0.01325	train-mlogloss:0.02410
# [61]	eval-mlogloss:0.01322	train-mlogloss:0.02402
# [62]	eval-mlogloss:0.01306	train-mlogloss:0.02393
# [63]	eval-mlogloss:0.01310	train-mlogloss:0.02384
# [64]	eval-mlogloss:0.01305	train-mlogloss:0.02377
# [65]	eval-mlogloss:0.01290	train-mlogloss:0.02366
# [66]	eval-mlogloss:0.01300	train-mlogloss:0.02357
# [67]	eval-mlogloss:0.01290	train-mlogloss:0.02347
# [68]	eval-mlogloss:0.01286	train-mlogloss:0.02340
# [69]	eval-mlogloss:0.01280	train-mlogloss:0.02331
# [70]	eval-mlogloss:0.01274	train-mlogloss:0.02320
# [71]	eval-mlogloss:0.01265	train-mlogloss:0.02314
# [72]	eval-mlogloss:0.01262	train-mlogloss:0.02309
# [73]	eval-mlogloss:0.01246	train-mlogloss:0.02293
# [74]	eval-mlogloss:0.01243	train-mlogloss:0.02290
# [75]	eval-mlogloss:0.01239	train-mlogloss:0.02284
# [76]	eval-mlogloss:0.01238	train-mlogloss:0.02281
# [77]	eval-mlogloss:0.01230	train-mlogloss:0.02274
# [78]	eval-mlogloss:0.01206	train-mlogloss:0.02264
# [79]	eval-mlogloss:0.01198	train-mlogloss:0.02254
# [80]	eval-mlogloss:0.01185	train-mlogloss:0.02248
# [81]	eval-mlogloss:0.01181	train-mlogloss:0.02243
# [82]	eval-mlogloss:0.01171	train-mlogloss:0.02236
# [83]	eval-mlogloss:0.01168	train-mlogloss:0.02233
# [84]	eval-mlogloss:0.01165	train-mlogloss:0.02229
# [85]	eval-mlogloss:0.01164	train-mlogloss:0.02225
# [86]	eval-mlogloss:0.01162	train-mlogloss:0.02221
# [87]	eval-mlogloss:0.01160	train-mlogloss:0.02217
# [88]	eval-mlogloss:0.01149	train-mlogloss:0.02211
# [89]	eval-mlogloss:0.01158	train-mlogloss:0.02202
# [90]	eval-mlogloss:0.01156	train-mlogloss:0.02199
# [91]	eval-mlogloss:0.01168	train-mlogloss:0.02194
# [92]	eval-mlogloss:0.01161	train-mlogloss:0.02187
# [93]	eval-mlogloss:0.01154	train-mlogloss:0.02182
# [94]	eval-mlogloss:0.01153	train-mlogloss:0.02178
# [95]	eval-mlogloss:0.01151	train-mlogloss:0.02173
# [96]	eval-mlogloss:0.01149	train-mlogloss:0.02170
# [97]	eval-mlogloss:0.01135	train-mlogloss:0.02162
# [98]	eval-mlogloss:0.01124	train-mlogloss:0.02158
# [99]	eval-mlogloss:0.01123	train-mlogloss:0.02156
# [0]	eval-mlogloss:0.82036	train-mlogloss:0.83361
# [1]	eval-mlogloss:0.62277	train-mlogloss:0.64661
# [2]	eval-mlogloss:0.48709	train-mlogloss:0.52143
# [3]	eval-mlogloss:0.39615	train-mlogloss:0.43226
# [4]	eval-mlogloss:0.32280	train-mlogloss:0.36215
# [5]	eval-mlogloss:0.25719	train-mlogloss:0.29928
# [6]	eval-mlogloss:0.20780	train-mlogloss:0.24921
# [7]	eval-mlogloss:0.16923	train-mlogloss:0.21355
# [8]	eval-mlogloss:0.13818	train-mlogloss:0.18530
# [9]	eval-mlogloss:0.11193	train-mlogloss:0.16066
# [10]	eval-mlogloss:0.09711	train-mlogloss:0.14211
# [11]	eval-mlogloss:0.08316	train-mlogloss:0.12466
# [12]	eval-mlogloss:0.07093	train-mlogloss:0.10950
# [13]	eval-mlogloss:0.06081	train-mlogloss:0.09975
# [14]	eval-mlogloss:0.05417	train-mlogloss:0.09199
# [15]	eval-mlogloss:0.04654	train-mlogloss:0.08548
# [16]	eval-mlogloss:0.03980	train-mlogloss:0.08111
# [17]	eval-mlogloss:0.03627	train-mlogloss:0.07857
# [18]	eval-mlogloss:0.03230	train-mlogloss:0.07477
# [19]	eval-mlogloss:0.03090	train-mlogloss:0.07278
# [20]	eval-mlogloss:0.02918	train-mlogloss:0.07120
# [21]	eval-mlogloss:0.02838	train-mlogloss:0.06876
# [22]	eval-mlogloss:0.03075	train-mlogloss:0.06775
# [23]	eval-mlogloss:0.03237	train-mlogloss:0.06720
# [24]	eval-mlogloss:0.02918	train-mlogloss:0.06348
# [25]	eval-mlogloss:0.02507	train-mlogloss:0.06180
# [26]	eval-mlogloss:0.02468	train-mlogloss:0.06081
# [27]	eval-mlogloss:0.02196	train-mlogloss:0.06097
# [28]	eval-mlogloss:0.02124	train-mlogloss:0.06067
# [29]	eval-mlogloss:0.02003	train-mlogloss:0.05932
# [30]	eval-mlogloss:0.01925	train-mlogloss:0.05819
# [31]	eval-mlogloss:0.01875	train-mlogloss:0.05740
# [32]	eval-mlogloss:0.01955	train-mlogloss:0.05764
# [33]	eval-mlogloss:0.01976	train-mlogloss:0.05631
# [34]	eval-mlogloss:0.02165	train-mlogloss:0.05466
# [35]	eval-mlogloss:0.02142	train-mlogloss:0.05441
# [36]	eval-mlogloss:0.02068	train-mlogloss:0.05391
# [37]	eval-mlogloss:0.02014	train-mlogloss:0.05236
# [38]	eval-mlogloss:0.01984	train-mlogloss:0.05148
# [39]	eval-mlogloss:0.01875	train-mlogloss:0.05161
# [40]	eval-mlogloss:0.01783	train-mlogloss:0.05135
# [41]	eval-mlogloss:0.01782	train-mlogloss:0.05017
# [42]	eval-mlogloss:0.01726	train-mlogloss:0.05027
# [43]	eval-mlogloss:0.01665	train-mlogloss:0.05048
# [44]	eval-mlogloss:0.01739	train-mlogloss:0.04822
# [45]	eval-mlogloss:0.01633	train-mlogloss:0.04798
# [46]	eval-mlogloss:0.01526	train-mlogloss:0.04808
# [47]	eval-mlogloss:0.01517	train-mlogloss:0.04759
# [48]	eval-mlogloss:0.01467	train-mlogloss:0.04705
# [49]	eval-mlogloss:0.01473	train-mlogloss:0.04672
# [50]	eval-mlogloss:0.01442	train-mlogloss:0.04666
# [51]	eval-mlogloss:0.01499	train-mlogloss:0.04604
# [52]	eval-mlogloss:0.01467	train-mlogloss:0.04520
# [53]	eval-mlogloss:0.01379	train-mlogloss:0.04501
# [54]	eval-mlogloss:0.01319	train-mlogloss:0.04431
# [55]	eval-mlogloss:0.01274	train-mlogloss:0.04391
# [56]	eval-mlogloss:0.01310	train-mlogloss:0.04387
# [57]	eval-mlogloss:0.01275	train-mlogloss:0.04316
# [58]	eval-mlogloss:0.01356	train-mlogloss:0.04328
# [59]	eval-mlogloss:0.01383	train-mlogloss:0.04340
# [60]	eval-mlogloss:0.01326	train-mlogloss:0.04304
# [61]	eval-mlogloss:0.01361	train-mlogloss:0.04254
# [62]	eval-mlogloss:0.01292	train-mlogloss:0.04240
# [63]	eval-mlogloss:0.01339	train-mlogloss:0.04257
# [64]	eval-mlogloss:0.01354	train-mlogloss:0.04277
# [65]	eval-mlogloss:0.01376	train-mlogloss:0.04289
# [66]	eval-mlogloss:0.01328	train-mlogloss:0.04251
# [67]	eval-mlogloss:0.01335	train-mlogloss:0.04234
# [68]	eval-mlogloss:0.01268	train-mlogloss:0.04116
# [69]	eval-mlogloss:0.01398	train-mlogloss:0.04126
# [70]	eval-mlogloss:0.01394	train-mlogloss:0.04108
# [71]	eval-mlogloss:0.01352	train-mlogloss:0.04083
# [72]	eval-mlogloss:0.01407	train-mlogloss:0.04074
# [73]	eval-mlogloss:0.01330	train-mlogloss:0.04037
# [74]	eval-mlogloss:0.01230	train-mlogloss:0.03985
# [75]	eval-mlogloss:0.01271	train-mlogloss:0.03974
# [76]	eval-mlogloss:0.01271	train-mlogloss:0.03959
# [77]	eval-mlogloss:0.01295	train-mlogloss:0.03941
# [78]	eval-mlogloss:0.01213	train-mlogloss:0.03940
# [79]	eval-mlogloss:0.01242	train-mlogloss:0.03934
# [80]	eval-mlogloss:0.01191	train-mlogloss:0.03858
# [81]	eval-mlogloss:0.01171	train-mlogloss:0.03848
# [82]	eval-mlogloss:0.01240	train-mlogloss:0.03808
# [83]	eval-mlogloss:0.01232	train-mlogloss:0.03778
# [84]	eval-mlogloss:0.01219	train-mlogloss:0.03776
# [85]	eval-mlogloss:0.01257	train-mlogloss:0.03783
# [86]	eval-mlogloss:0.01356	train-mlogloss:0.03772
# [87]	eval-mlogloss:0.01312	train-mlogloss:0.03772
# [88]	eval-mlogloss:0.01324	train-mlogloss:0.03743
# [89]	eval-mlogloss:0.01265	train-mlogloss:0.03729
# [90]	eval-mlogloss:0.01304	train-mlogloss:0.03718
# [91]	eval-mlogloss:0.01273	train-mlogloss:0.03712
# [92]	eval-mlogloss:0.01288	train-mlogloss:0.03707
# [93]	eval-mlogloss:0.01263	train-mlogloss:0.03687
# [94]	eval-mlogloss:0.01264	train-mlogloss:0.03680
# [95]	eval-mlogloss:0.01234	train-mlogloss:0.03651
# [96]	eval-mlogloss:0.01188	train-mlogloss:0.03645
# [97]	eval-mlogloss:0.01158	train-mlogloss:0.03626
# [98]	eval-mlogloss:0.01153	train-mlogloss:0.03584
# [99]	eval-mlogloss:0.01116	train-mlogloss:0.03601
# [0]	eval-mlogloss:0.27758	train-mlogloss:0.32007
# [1]	eval-mlogloss:0.15314	train-mlogloss:0.16172
# [2]	eval-mlogloss:0.07539	train-mlogloss:0.08616
# [3]	eval-mlogloss:0.04980	train-mlogloss:0.06954
# [4]	eval-mlogloss:0.03638	train-mlogloss:0.06748
# [5]	eval-mlogloss:0.05112	train-mlogloss:0.06512
# [6]	eval-mlogloss:0.02776	train-mlogloss:0.04768
# [7]	eval-mlogloss:0.02453	train-mlogloss:0.04792
# [8]	eval-mlogloss:0.02601	train-mlogloss:0.04794
# [9]	eval-mlogloss:0.02052	train-mlogloss:0.04466
# [10]	eval-mlogloss:0.02094	train-mlogloss:0.04208
# [11]	eval-mlogloss:0.02397	train-mlogloss:0.04009
# [12]	eval-mlogloss:0.01940	train-mlogloss:0.03882
# [13]	eval-mlogloss:0.01894	train-mlogloss:0.03855
# [14]	eval-mlogloss:0.02474	train-mlogloss:0.04072
# [15]	eval-mlogloss:0.01929	train-mlogloss:0.04033
# [16]	eval-mlogloss:0.01901	train-mlogloss:0.03928
# [17]	eval-mlogloss:0.02090	train-mlogloss:0.04178
# [18]	eval-mlogloss:0.01873	train-mlogloss:0.03906
# [19]	eval-mlogloss:0.02300	train-mlogloss:0.03787
# [20]	eval-mlogloss:0.02355	train-mlogloss:0.03717
# [21]	eval-mlogloss:0.02387	train-mlogloss:0.03746
# [22]	eval-mlogloss:0.02404	train-mlogloss:0.03771
# [23]	eval-mlogloss:0.02667	train-mlogloss:0.03802
# [24]	eval-mlogloss:0.02621	train-mlogloss:0.03642
# [25]	eval-mlogloss:0.01984	train-mlogloss:0.03451
# [26]	eval-mlogloss:0.02058	train-mlogloss:0.03554
# [27]	eval-mlogloss:0.01972	train-mlogloss:0.03539
# [28]	eval-mlogloss:0.01937	train-mlogloss:0.03531
# [29]	eval-mlogloss:0.02411	train-mlogloss:0.03479
# [30]	eval-mlogloss:0.02024	train-mlogloss:0.03455
# [31]	eval-mlogloss:0.01919	train-mlogloss:0.03645
# [32]	eval-mlogloss:0.01880	train-mlogloss:0.03413
# [33]	eval-mlogloss:0.01859	train-mlogloss:0.03342
# [34]	eval-mlogloss:0.02095	train-mlogloss:0.03419
# [35]	eval-mlogloss:0.01817	train-mlogloss:0.03364
# [36]	eval-mlogloss:0.01901	train-mlogloss:0.03383
# [37]	eval-mlogloss:0.01551	train-mlogloss:0.03290
# [38]	eval-mlogloss:0.01432	train-mlogloss:0.03143
# [39]	eval-mlogloss:0.01542	train-mlogloss:0.03211
# [40]	eval-mlogloss:0.01543	train-mlogloss:0.03111
# [41]	eval-mlogloss:0.01676	train-mlogloss:0.03227
# [42]	eval-mlogloss:0.01461	train-mlogloss:0.03201
# [43]	eval-mlogloss:0.01487	train-mlogloss:0.03166
# [44]	eval-mlogloss:0.01416	train-mlogloss:0.03041
# [45]	eval-mlogloss:0.01605	train-mlogloss:0.03105
# [46]	eval-mlogloss:0.01495	train-mlogloss:0.03028
# [47]	eval-mlogloss:0.01515	train-mlogloss:0.02947
# [48]	eval-mlogloss:0.01436	train-mlogloss:0.02931
# [49]	eval-mlogloss:0.01369	train-mlogloss:0.02874
# [50]	eval-mlogloss:0.01324	train-mlogloss:0.02890
# [51]	eval-mlogloss:0.01266	train-mlogloss:0.02850
# [52]	eval-mlogloss:0.01253	train-mlogloss:0.02799
# [53]	eval-mlogloss:0.01291	train-mlogloss:0.02790
# [54]	eval-mlogloss:0.01360	train-mlogloss:0.02763
# [55]	eval-mlogloss:0.01238	train-mlogloss:0.02738
# [56]	eval-mlogloss:0.01244	train-mlogloss:0.02719
# [57]	eval-mlogloss:0.01208	train-mlogloss:0.02660
# [58]	eval-mlogloss:0.01322	train-mlogloss:0.02670
# [59]	eval-mlogloss:0.01368	train-mlogloss:0.02724
# [60]	eval-mlogloss:0.01338	train-mlogloss:0.02680
# [61]	eval-mlogloss:0.01430	train-mlogloss:0.02685
# [62]	eval-mlogloss:0.01283	train-mlogloss:0.02673
# [63]	eval-mlogloss:0.01269	train-mlogloss:0.02652
# [64]	eval-mlogloss:0.01316	train-mlogloss:0.02751
# [65]	eval-mlogloss:0.01325	train-mlogloss:0.02674
# [66]	eval-mlogloss:0.01277	train-mlogloss:0.02628
# [67]	eval-mlogloss:0.01277	train-mlogloss:0.02628
# [68]	eval-mlogloss:0.01237	train-mlogloss:0.02589
# [69]	eval-mlogloss:0.01323	train-mlogloss:0.02664
# [70]	eval-mlogloss:0.01285	train-mlogloss:0.02598
# [71]	eval-mlogloss:0.01286	train-mlogloss:0.02597
# [72]	eval-mlogloss:0.01379	train-mlogloss:0.02688
# [73]	eval-mlogloss:0.01286	train-mlogloss:0.02587
# [74]	eval-mlogloss:0.01375	train-mlogloss:0.02629
# [75]	eval-mlogloss:0.01433	train-mlogloss:0.02700
# [76]	eval-mlogloss:0.01265	train-mlogloss:0.02605
# [77]	eval-mlogloss:0.01275	train-mlogloss:0.02597
# ...
# [75]	eval-mlogloss:0.01200	train-mlogloss:0.02171
# [76]	eval-mlogloss:0.01221	train-mlogloss:0.02171
# [77]	eval-mlogloss:0.01226	train-mlogloss:0.02165
# [78]	eval-mlogloss:0.01154	train-mlogloss:0.02173
# [79]	eval-mlogloss:0.01161	train-mlogloss:0.02176
# [80]	eval-mlogloss:0.01177	train-mlogloss:0.02184
# [81]	eval-mlogloss:0.01181	train-mlogloss:0.02196
# [82]	eval-mlogloss:0.01195	train-mlogloss:0.02161
# [83]	eval-mlogloss:0.01121	train-mlogloss:0.02164
# [84]	eval-mlogloss:0.01106	train-mlogloss:0.02164
# [85]	eval-mlogloss:0.01103	train-mlogloss:0.02167
# [86]	eval-mlogloss:0.01140	train-mlogloss:0.02158
# [87]	eval-mlogloss:0.01136	train-mlogloss:0.02153
# [88]	eval-mlogloss:0.01190	train-mlogloss:0.02159
# [89]	eval-mlogloss:0.01226	train-mlogloss:0.02154
# [90]	eval-mlogloss:0.01267	train-mlogloss:0.02164
# [91]	eval-mlogloss:0.01231	train-mlogloss:0.02161
# [92]	eval-mlogloss:0.01228	train-mlogloss:0.02148
# [93]	eval-mlogloss:0.01191	train-mlogloss:0.02142
# [94]	eval-mlogloss:0.01219	train-mlogloss:0.02142
# [95]	eval-mlogloss:0.01229	train-mlogloss:0.02140
# [96]	eval-mlogloss:0.01272	train-mlogloss:0.02140
# [97]	eval-mlogloss:0.01269	train-mlogloss:0.02143
# [98]	eval-mlogloss:0.01272	train-mlogloss:0.02141
# [99]	eval-mlogloss:0.01245	train-mlogloss:0.02132
# [0]	eval-mlogloss:0.45316	train-mlogloss:0.48473
# [1]	eval-mlogloss:0.24261	train-mlogloss:0.28965
# [2]	eval-mlogloss:0.14512	train-mlogloss:0.19921
# [3]	eval-mlogloss:0.09906	train-mlogloss:0.15139
# [4]	eval-mlogloss:0.07132	train-mlogloss:0.12589
# [5]	eval-mlogloss:0.05309	train-mlogloss:0.10690
# [6]	eval-mlogloss:0.04367	train-mlogloss:0.09182
# [7]	eval-mlogloss:0.03809	train-mlogloss:0.08642
# [8]	eval-mlogloss:0.03558	train-mlogloss:0.08217
# [9]	eval-mlogloss:0.03126	train-mlogloss:0.07720
# [10]	eval-mlogloss:0.03008	train-mlogloss:0.07567
# [11]	eval-mlogloss:0.02994	train-mlogloss:0.07385
# [12]	eval-mlogloss:0.02875	train-mlogloss:0.07301
# [13]	eval-mlogloss:0.02868	train-mlogloss:0.07056
# [14]	eval-mlogloss:0.02928	train-mlogloss:0.06828
# [15]	eval-mlogloss:0.02857	train-mlogloss:0.06711
# [16]	eval-mlogloss:0.02787	train-mlogloss:0.06517
# [17]	eval-mlogloss:0.02702	train-mlogloss:0.06457
# [18]	eval-mlogloss:0.02683	train-mlogloss:0.06314
# [19]	eval-mlogloss:0.02634	train-mlogloss:0.06218
# [20]	eval-mlogloss:0.02508	train-mlogloss:0.06061
# [21]	eval-mlogloss:0.02508	train-mlogloss:0.05982
# [22]	eval-mlogloss:0.02470	train-mlogloss:0.05800
# [23]	eval-mlogloss:0.02402	train-mlogloss:0.05759
# [24]	eval-mlogloss:0.02368	train-mlogloss:0.05714
# [25]	eval-mlogloss:0.02311	train-mlogloss:0.05684
# [26]	eval-mlogloss:0.02305	train-mlogloss:0.05692
# [27]	eval-mlogloss:0.02309	train-mlogloss:0.05662
# [28]	eval-mlogloss:0.02301	train-mlogloss:0.05599
# [29]	eval-mlogloss:0.02307	train-mlogloss:0.05567
# [30]	eval-mlogloss:0.02307	train-mlogloss:0.05567
# [31]	eval-mlogloss:0.02251	train-mlogloss:0.05498
# [32]	eval-mlogloss:0.02305	train-mlogloss:0.05429
# [33]	eval-mlogloss:0.02315	train-mlogloss:0.05406
# [34]	eval-mlogloss:0.02315	train-mlogloss:0.05406
# [35]	eval-mlogloss:0.02315	train-mlogloss:0.05406
# [36]	eval-mlogloss:0.02298	train-mlogloss:0.05324
# [37]	eval-mlogloss:0.02298	train-mlogloss:0.05324
# [38]	eval-mlogloss:0.02298	train-mlogloss:0.05324
# [39]	eval-mlogloss:0.02235	train-mlogloss:0.05315
# [40]	eval-mlogloss:0.02206	train-mlogloss:0.05312
# [41]	eval-mlogloss:0.02234	train-mlogloss:0.05298
# [42]	eval-mlogloss:0.02228	train-mlogloss:0.05273
# [43]	eval-mlogloss:0.02228	train-mlogloss:0.05273
# [44]	eval-mlogloss:0.02222	train-mlogloss:0.05255
# [45]	eval-mlogloss:0.02222	train-mlogloss:0.05235
# [46]	eval-mlogloss:0.02208	train-mlogloss:0.05201
# [47]	eval-mlogloss:0.02206	train-mlogloss:0.05200
# [48]	eval-mlogloss:0.02122	train-mlogloss:0.05182
# [49]	eval-mlogloss:0.02122	train-mlogloss:0.05182
# [50]	eval-mlogloss:0.02122	train-mlogloss:0.05182
# [51]	eval-mlogloss:0.02117	train-mlogloss:0.05179
# [52]	eval-mlogloss:0.02136	train-mlogloss:0.05107
# [53]	eval-mlogloss:0.02136	train-mlogloss:0.05107
# [54]	eval-mlogloss:0.02139	train-mlogloss:0.05094
# [55]	eval-mlogloss:0.02139	train-mlogloss:0.05094
# [56]	eval-mlogloss:0.02139	train-mlogloss:0.05094
# [57]	eval-mlogloss:0.02139	train-mlogloss:0.05094
# [58]	eval-mlogloss:0.02137	train-mlogloss:0.05092
# [59]	eval-mlogloss:0.02137	train-mlogloss:0.05092
# [60]	eval-mlogloss:0.02137	train-mlogloss:0.05092
# [61]	eval-mlogloss:0.02163	train-mlogloss:0.05067
# [62]	eval-mlogloss:0.02154	train-mlogloss:0.05067
# [63]	eval-mlogloss:0.02154	train-mlogloss:0.05067
# [64]	eval-mlogloss:0.02210	train-mlogloss:0.05039
# [65]	eval-mlogloss:0.02182	train-mlogloss:0.05008
# [66]	eval-mlogloss:0.02219	train-mlogloss:0.04966
# [67]	eval-mlogloss:0.02204	train-mlogloss:0.04948
# [68]	eval-mlogloss:0.02204	train-mlogloss:0.04948
# [69]	eval-mlogloss:0.02168	train-mlogloss:0.04901
# [70]	eval-mlogloss:0.02168	train-mlogloss:0.04901
# [71]	eval-mlogloss:0.02168	train-mlogloss:0.04899
# [72]	eval-mlogloss:0.02184	train-mlogloss:0.04852
# [73]	eval-mlogloss:0.02100	train-mlogloss:0.04836
# [74]	eval-mlogloss:0.02100	train-mlogloss:0.04836
# [75]	eval-mlogloss:0.02113	train-mlogloss:0.04799
# [76]	eval-mlogloss:0.02118	train-mlogloss:0.04790
# [77]	eval-mlogloss:0.02118	train-mlogloss:0.04790
# [78]	eval-mlogloss:0.02076	train-mlogloss:0.04760
# [79]	eval-mlogloss:0.02076	train-mlogloss:0.04760
# [80]	eval-mlogloss:0.02073	train-mlogloss:0.04743
# [81]	eval-mlogloss:0.02019	train-mlogloss:0.04774
# [82]	eval-mlogloss:0.02014	train-mlogloss:0.04631
# [83]	eval-mlogloss:0.01997	train-mlogloss:0.04622
# [84]	eval-mlogloss:0.01953	train-mlogloss:0.04607
# [85]	eval-mlogloss:0.01944	train-mlogloss:0.04604
# [86]	eval-mlogloss:0.01944	train-mlogloss:0.04604
# [87]	eval-mlogloss:0.01907	train-mlogloss:0.04598
# [88]	eval-mlogloss:0.01907	train-mlogloss:0.04598
# [89]	eval-mlogloss:0.01908	train-mlogloss:0.04597
# [90]	eval-mlogloss:0.01926	train-mlogloss:0.04565
# [91]	eval-mlogloss:0.01916	train-mlogloss:0.04536
# [92]	eval-mlogloss:0.01916	train-mlogloss:0.04536
# [93]	eval-mlogloss:0.01916	train-mlogloss:0.04536
# [94]	eval-mlogloss:0.01908	train-mlogloss:0.04528
# [95]	eval-mlogloss:0.01908	train-mlogloss:0.04528
# [96]	eval-mlogloss:0.01872	train-mlogloss:0.04474
# [97]	eval-mlogloss:0.01867	train-mlogloss:0.04467
# [98]	eval-mlogloss:0.01867	train-mlogloss:0.04467
# [99]	eval-mlogloss:0.01867	train-mlogloss:0.04467
# 100%|███████████████████████████████████████████████████████████████████████| 10/10 [00:04<00:00,  2.36trial/s, best loss: 0.0]

# %%
trials.results
# Out:
# [{'loss': 0.0, 'status': 'ok'},
#  {'loss': 0.0, 'status': 'ok'},
#  {'loss': 0.0, 'status': 'ok'},
#  {'loss': 0.0, 'status': 'ok'},
#  {'loss': 0.0, 'status': 'ok'},
#  {'loss': 0.0, 'status': 'ok'},
#  {'loss': 0.0, 'status': 'ok'},
#  {'loss': 0.0, 'status': 'ok'},
#  {'loss': 0.0, 'status': 'ok'},
#  {'loss': 0.0, 'status': 'ok'}]

# %%
trials.best_trial
# Out:
# {'state': 2,
#  'tid': 0,
#  'spec': None,
#  'result': {'loss': 0.0, 'status': 'ok'},
#  'misc': {'tid': 0,
#   'cmd': ('domain_attachment', 'FMinIter_Domain'),
#   'workdir': None,
#   'idxs': {'alpha': [0],
#    'eta': [0],
#    'lambda': [0],
#    'max_depth': [0],
#    'subsample': [0]},
#   'vals': {'alpha': [0.007820051655776247],
#    'eta': [0.08707059692675438],
#    'lambda': [0.10721982631307697],
#    'max_depth': [10.0],
#    'subsample': [0.7419833312630884]}},
#  'exp_key': None,
#  'owner': None,
#  'version': 0,
#  'book_time': datetime.datetime(2023, 7, 15, 21, 52, 43, 366000),
#  'refresh_time': datetime.datetime(2023, 7, 15, 21, 52, 43, 803000)}

# %%
best['max_depth'] = int(best['max_depth'])

best
# Out:
# {'alpha': 0.007820051655776247,
#  'eta': 0.08707059692675438,
#  'lambda': 0.10721982631307697,
#  'max_depth': 10,
#  'subsample': 0.7419833312630884}

# %%
booster = xgb.train(
    params=best,
    dtrain=dtrain,
    num_boost_round=num_round,
    evals=watchlist,
    early_stopping_rounds=early_stopping_rounds
)

y_pred = booster.predict(dval)
print(y_pred[:5])

rmse = mean_squared_error(y_val, y_pred, squared=False)
print(f"RMSE: {rmse}")
# Out:
# [0]	eval-rmse:0.85645	train-rmse:0.88062
# [1]	eval-rmse:0.78224	train-rmse:0.80386
# [2]	eval-rmse:0.71447	train-rmse:0.73762
# [3]	eval-rmse:0.65254	train-rmse:0.67639
# [4]	eval-rmse:0.59524	train-rmse:0.62256
# [5]	eval-rmse:0.54363	train-rmse:0.56922
# [6]	eval-rmse:0.49646	train-rmse:0.52099
# [7]	eval-rmse:0.45300	train-rmse:0.47846
# [8]	eval-rmse:0.42258	train-rmse:0.44221
# [9]	eval-rmse:0.38644	train-rmse:0.40625
# [10]	eval-rmse:0.35349	train-rmse:0.37336
# [11]	eval-rmse:0.32345	train-rmse:0.34443
# [12]	eval-rmse:0.29589	train-rmse:0.31478
# [13]	eval-rmse:0.27093	train-rmse:0.28960
# [14]	eval-rmse:0.24803	train-rmse:0.26613
# [15]	eval-rmse:0.22723	train-rmse:0.24522
# [16]	eval-rmse:0.20798	train-rmse:0.22479
# [17]	eval-rmse:0.18992	train-rmse:0.20822
# [18]	eval-rmse:0.17718	train-rmse:0.19197
# [19]	eval-rmse:0.16468	train-rmse:0.17718
# [20]	eval-rmse:0.15167	train-rmse:0.16415
# [21]	eval-rmse:0.13977	train-rmse:0.15014
# [22]	eval-rmse:0.12914	train-rmse:0.13748
# [23]	eval-rmse:0.11770	train-rmse:0.12691
# [24]	eval-rmse:0.10902	train-rmse:0.11625
# [25]	eval-rmse:0.10184	train-rmse:0.10674
# [26]	eval-rmse:0.09457	train-rmse:0.09811
# [27]	eval-rmse:0.08785	train-rmse:0.09022
# [28]	eval-rmse:0.08163	train-rmse:0.08382
# [29]	eval-rmse:0.07648	train-rmse:0.07747
# [30]	eval-rmse:0.07168	train-rmse:0.07248
# [31]	eval-rmse:0.06740	train-rmse:0.06760
# [32]	eval-rmse:0.06348	train-rmse:0.06193
# [33]	eval-rmse:0.05960	train-rmse:0.05782
# [34]	eval-rmse:0.05617	train-rmse:0.05359
# [35]	eval-rmse:0.05394	train-rmse:0.05029
# [36]	eval-rmse:0.05084	train-rmse:0.04711
# [37]	eval-rmse:0.04807	train-rmse:0.04381
# [38]	eval-rmse:0.04642	train-rmse:0.04072
# [39]	eval-rmse:0.04487	train-rmse:0.03832
# [40]	eval-rmse:0.04413	train-rmse:0.03614
# [41]	eval-rmse:0.04298	train-rmse:0.03365
# [42]	eval-rmse:0.04168	train-rmse:0.03190
# [43]	eval-rmse:0.04073	train-rmse:0.03034
# [44]	eval-rmse:0.04001	train-rmse:0.02835
# [45]	eval-rmse:0.03980	train-rmse:0.02696
# [46]	eval-rmse:0.03921	train-rmse:0.02482
# [47]	eval-rmse:0.03943	train-rmse:0.02332
# [48]	eval-rmse:0.03908	train-rmse:0.02213
# [49]	eval-rmse:0.03858	train-rmse:0.02107
# [50]	eval-rmse:0.03832	train-rmse:0.02040
# [51]	eval-rmse:0.03789	train-rmse:0.01951
# [52]	eval-rmse:0.03762	train-rmse:0.01834
# [53]	eval-rmse:0.03716	train-rmse:0.01782
# [54]	eval-rmse:0.03702	train-rmse:0.01693
# [55]	eval-rmse:0.03677	train-rmse:0.01604
# [56]	eval-rmse:0.03657	train-rmse:0.01528
# [57]	eval-rmse:0.03656	train-rmse:0.01436
# [58]	eval-rmse:0.03636	train-rmse:0.01362
# [59]	eval-rmse:0.03625	train-rmse:0.01303
# [60]	eval-rmse:0.03614	train-rmse:0.01250
# [61]	eval-rmse:0.03622	train-rmse:0.01208
# [62]	eval-rmse:0.03601	train-rmse:0.01149
# [63]	eval-rmse:0.03611	train-rmse:0.01120
# [64]	eval-rmse:0.03619	train-rmse:0.01074
# [65]	eval-rmse:0.03609	train-rmse:0.01046
# [66]	eval-rmse:0.03608	train-rmse:0.01013
# [67]	eval-rmse:0.03590	train-rmse:0.00961
# [68]	eval-rmse:0.03578	train-rmse:0.00943
# [69]	eval-rmse:0.03567	train-rmse:0.00899
# [70]	eval-rmse:0.03561	train-rmse:0.00852
# [71]	eval-rmse:0.03568	train-rmse:0.00816
# [72]	eval-rmse:0.03588	train-rmse:0.00791
# [73]	eval-rmse:0.03583	train-rmse:0.00767
# [74]	eval-rmse:0.03551	train-rmse:0.00728
# [75]	eval-rmse:0.03560	train-rmse:0.00704
# [76]	eval-rmse:0.03555	train-rmse:0.00686
# [77]	eval-rmse:0.03546	train-rmse:0.00649
# [78]	eval-rmse:0.03552	train-rmse:0.00627
# [79]	eval-rmse:0.03547	train-rmse:0.00607
# [80]	eval-rmse:0.03533	train-rmse:0.00582
# [81]	eval-rmse:0.03528	train-rmse:0.00566
# [82]	eval-rmse:0.03512	train-rmse:0.00553
# [83]	eval-rmse:0.03512	train-rmse:0.00543
# [84]	eval-rmse:0.03513	train-rmse:0.00532
# [85]	eval-rmse:0.03515	train-rmse:0.00513
# [86]	eval-rmse:0.03510	train-rmse:0.00509
# [87]	eval-rmse:0.03516	train-rmse:0.00496
# [88]	eval-rmse:0.03516	train-rmse:0.00485
# [89]	eval-rmse:0.03515	train-rmse:0.00471
# [90]	eval-rmse:0.03516	train-rmse:0.00461
# [91]	eval-rmse:0.03514	train-rmse:0.00450
# [92]	eval-rmse:0.03514	train-rmse:0.00436
# [93]	eval-rmse:0.03505	train-rmse:0.00423
# [94]	eval-rmse:0.03508	train-rmse:0.00417
# [95]	eval-rmse:0.03509	train-rmse:0.00408
# [96]	eval-rmse:0.03501	train-rmse:0.00400
# [97]	eval-rmse:0.03494	train-rmse:0.00395
# [98]	eval-rmse:0.03496	train-rmse:0.00390
# [99]	eval-rmse:0.03491	train-rmse:0.00382
# [1.0031559e+00 4.2965857e-04 2.0128312e+00 1.0087540e+00 9.6262246e-01]
# RMSE: 0.03490594024366397

# %%
y_pred_round = np.round(y_pred)
y_pred_round[:5]
# Out:
# array([1., 0., 2., 1., 1.], dtype=float32)

# %%
y_val[:5]
# Out:
# array([1, 0, 2, 1, 1])
