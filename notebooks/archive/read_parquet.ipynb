# %%
import pandas as pd
pd.__version__
# Out:
# '2.0.3'

# %%
df_01 = pd.read_parquet('./../data/green_tripdata_2022-01.parquet')
df_01.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2022-01-01 00:14:21   2022-01-01 00:15:33                  N
# 1         1  2022-01-01 00:20:55   2022-01-01 00:29:38                  N
# 2         1  2022-01-01 00:57:02   2022-01-01 01:13:14                  N
# 3         2  2022-01-01 00:07:42   2022-01-01 00:15:57                  N
# 4         2  2022-01-01 00:07:50   2022-01-01 00:28:52                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            42            42              1.0           0.44
# 1         1.0           116            41              1.0           2.10
# 2         1.0            41           140              1.0           3.70
# 3         1.0           181           181              1.0           1.69
# 4         1.0            33           170              1.0           6.26
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# ...

# %%
df_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62495 entries, 0 to 62494
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               62495 non-null  int64
#  1   lpep_pickup_datetime   62495 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  62495 non-null  datetime64[ns]
#  3   store_and_fwd_flag     56200 non-null  object
#  4   RatecodeID             56200 non-null  float64
#  5   PULocationID           62495 non-null  int64
#  6   DOLocationID           62495 non-null  int64
#  7   passenger_count        56200 non-null  float64
#  8   trip_distance          62495 non-null  float64
#  9   fare_amount            62495 non-null  float64
#  10  extra                  62495 non-null  float64
#  11  mta_tax                62495 non-null  float64
#  12  tip_amount             62495 non-null  float64
#  13  tolls_amount           62495 non-null  float64
# ...

# %%
df_02 = pd.read_parquet('./../data/green_tripdata_2022-02.parquet')
df_02.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2022-02-01 00:20:21   2022-02-01 00:24:30                  N
# 1         2  2022-02-01 00:32:26   2022-02-01 00:35:31                  N
# 2         1  2022-02-01 00:17:27   2022-02-01 00:44:44                  N
# 3         2  2022-02-01 00:45:37   2022-02-01 01:27:16                  N
# 4         2  2022-02-01 00:06:46   2022-02-01 00:30:06                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            43           238              1.0           1.16
# 1         1.0           166            24              1.0           0.57
# 2         1.0           226           219              1.0           0.00
# 3         1.0            89            83              1.0          16.62
# 4         1.0             7           238              1.0           5.97
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# ...

# %%
df_03 = pd.read_parquet('./../data/green_tripdata_2022-03.parquet')
df_03.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         1  2022-03-01 00:24:14   2022-03-01 00:34:04                  N
# 1         2  2022-02-28 23:39:24   2022-02-28 23:47:03                  N
# 2         2  2022-02-28 23:55:30   2022-03-01 00:09:32                  N
# 3         2  2022-03-01 00:24:55   2022-03-01 00:33:06                  N
# 4         2  2022-03-01 00:23:33   2022-03-01 00:30:08                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74           151              1.0           2.30
# 1         1.0            75           151              1.0           1.31
# 2         1.0           166            42              1.0           2.31
# 3         1.0            82           173              1.0           1.58
# 4         1.0           127           243              1.0           1.52
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# ...

# %%
df = pd.concat([df_01, df_02, df_03], ignore_index=True)
df.sample(12)
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 46835          2  2022-01-26 07:57:48   2022-01-27 07:48:21
# 175601         2  2022-03-20 15:30:27   2022-03-20 15:40:05
# 73873          2  2022-02-05 23:08:59   2022-02-05 23:21:42
# 24794          1  2022-01-14 15:44:27   2022-01-14 15:57:04
# 125297         2  2022-02-03 19:02:00   2022-02-03 19:18:00
# 55574          1  2022-01-31 17:05:48   2022-01-31 17:18:00
# 207580         2  2022-03-20 18:21:00   2022-03-20 18:54:00
# 148915         2  2022-03-08 15:08:12   2022-03-08 15:54:13
# 65843          1  2022-02-02 15:21:57   2022-02-02 15:28:11
# 197851         2  2022-03-30 09:51:41   2022-03-30 09:59:35
# 117560         2  2022-02-25 17:21:04   2022-02-25 17:25:11
# 130515         2  2022-02-23 12:19:00   2022-02-23 12:41:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 46835                   N         1.0            75            52
# ...

# %%
( # check for number of NULL records in each column
    df
    .isnull()
    .sum(axis=0) 
)
# Out:
# VendorID                      0
# lpep_pickup_datetime          0
# lpep_dropoff_datetime         0
# store_and_fwd_flag        21781
# RatecodeID                21781
# PULocationID                  0
# DOLocationID                  0
# passenger_count           21781
# trip_distance                 0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# ehail_fee                210431
# improvement_surcharge         0
# total_amount                  0
# payment_type              21781
# trip_type                 21782
# congestion_surcharge      21781
# dtype: int64
